# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import*
# %matplotlib inline 

import seaborn as sns

# %%
sleep = pd.read_csv('sleep.csv')

# %% [markdown]
# ### 查看缺失值情况

# %%
sleep.head()
# Out:
#     BodyWgt  BrainWgt  NonD  Dream  Sleep  Span   Gest  Pred  Exp  Danger
# 0  6654.000    5712.0   NaN    NaN    3.3  38.6  645.0     3    5       3
# 1     1.000       6.6   6.3    2.0    8.3   4.5   42.0     3    1       3
# 2     3.385      44.5   NaN    NaN   12.5  14.0   60.0     1    1       1
# 3     0.920       5.7   NaN    NaN   16.5   NaN   25.0     5    2       3
# 4  2547.000    4603.0   2.1    1.8    3.9  69.0  624.0     3    5       4

# %%
sleep.isnull().sum()
# Out:
# BodyWgt      0
# BrainWgt     0
# NonD        14
# Dream       12
# Sleep        4
# Span         4
# Gest         4
# Pred         0
# Exp          0
# Danger       0
# dtype: int64

# %% [markdown]
# ### 实现类似R中mice包的 md.patten() 的作用

# %%
def md_patten(data):
    """
    Display missing-data patterns. and highlight the missing values
    """
    df = data.isnull().replace({True:-1,False:0})
    df['.Row_Nums'] = 1

    df1 = df.groupby(by=list(data.columns)).agg(sum).sort_values('.Row_Nums',ascending =False).reset_index()
    df2 = data.isnull().sum().to_frame().T.rename(index = {0:' '})
    tem = pd.concat([df1,df2]).fillna('Missing_Nums')
    return tem

# %%
md_patten(sleep)
# Out:
#       .Row_Nums  BodyWgt  BrainWgt  Danger  Dream  Exp  Gest  NonD  Pred  \
# 0            42        0         0       0      0    0     0     0     0
# 1             9        0         0       0     -1    0     0    -1     0
# 2             3        0         0       0      0    0    -1     0     0
# 3             2        0         0       0     -1    0     0    -1     0
# 4             2        0         0       0      0    0     0    -1     0
# 5             2        0         0       0      0    0     0     0     0
# 6             1        0         0       0     -1    0     0    -1     0
# 7             1        0         0       0      0    0    -1     0     0
#    Missing_Nums        0         0       0     12    0     4    14     0
#
#    Sleep  Span
# 0      0     0
# 1      0     0
# 2      0     0
# 3     -1     0
# 4     -1     0
# 5      0    -1
# 6      0    -1
# 7      0    -1
#        4     4

# %% [markdown]
# ### 利用pandas style 以及 seaborn 可视化缺失值

# %% [markdown]
# #### 利数字标注缺失值，并绘图

# %%
def showHight(col):
    """
    Highlight certain values.
    """
    c = col ==-1
    #c = col ==col.max()
    return ['background-color:red' if v else ' ' for v in c]


def aggr(data,plot =True,figsize = (9,8)):
    """
    1. Display missing-data patterns. and highlight the missing values.
    2. Plot the missing values in each variable using bar plot.
    3. Plot the missing values in certain combinations of variables using aggregation plot(heatmap vi Seaborn).
    """
    df = data.isnull().replace({True:-1,False:0})
    df['.Row_Nums'] = 1

    df1 = df.groupby(by=list(data.columns)).agg(sum).sort_values('.Row_Nums',ascending =False).reset_index()
    df2 = data.isnull().sum().to_frame().T.rename(index = {0:' '})
    tem = pd.concat([df1,df2])
    if plot:
        # bar plot
        data.isnull().sum().to_frame().plot(kind ='bar',figsize = (10,9),legend = False)
        
        # aggregation plot
        plt.figure(figsize=(10,9))
        sns.heatmap(tem,vmax =0.0,cmap = 'OrRd_r',linecolor='white',linewidths=0.1, annot=True,cbar =False) 
        
    return tem.fillna('Missing_Nums').style.apply(showHight)

# %%
aggr(sleep)
# Out:
# <style  type="text/css" >
#     #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col4 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col7 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col6 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col4 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col7 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col9 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col7 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col9 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row5_col10 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row6_col4 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row6_col7 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row6_col10 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row7_col6 {
#             background-color: red;
#         }    #T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row7_col10 {
#             background-color: red;
#         }</style>
# <table id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >.Row_Nums</th>
#         <th class="col_heading level0 col1" >BodyWgt</th>
#         <th class="col_heading level0 col2" >BrainWgt</th>
#         <th class="col_heading level0 col3" >Danger</th>
#         <th class="col_heading level0 col4" >Dream</th>
#         <th class="col_heading level0 col5" >Exp</th>
#         <th class="col_heading level0 col6" >Gest</th>
#         <th class="col_heading level0 col7" >NonD</th>
#         <th class="col_heading level0 col8" >Pred</th>
#         <th class="col_heading level0 col9" >Sleep</th>
#         <th class="col_heading level0 col10" >Span</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col0" class="data row0 col0" >42</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col1" class="data row0 col1" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col2" class="data row0 col2" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col3" class="data row0 col3" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col4" class="data row0 col4" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col5" class="data row0 col5" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col6" class="data row0 col6" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col7" class="data row0 col7" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col8" class="data row0 col8" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col9" class="data row0 col9" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row0_col10" class="data row0 col10" >0</td>
#     </tr>    <tr>
#         <th id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col0" class="data row1 col0" >9</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col1" class="data row1 col1" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col2" class="data row1 col2" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col3" class="data row1 col3" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col4" class="data row1 col4" >-1</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col5" class="data row1 col5" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col6" class="data row1 col6" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col7" class="data row1 col7" >-1</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col8" class="data row1 col8" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col9" class="data row1 col9" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row1_col10" class="data row1 col10" >0</td>
#     </tr>    <tr>
#         <th id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col0" class="data row2 col0" >3</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col1" class="data row2 col1" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col2" class="data row2 col2" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col3" class="data row2 col3" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col4" class="data row2 col4" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col5" class="data row2 col5" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col6" class="data row2 col6" >-1</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col7" class="data row2 col7" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col8" class="data row2 col8" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col9" class="data row2 col9" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row2_col10" class="data row2 col10" >0</td>
#     </tr>    <tr>
#         <th id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col0" class="data row3 col0" >2</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col1" class="data row3 col1" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col2" class="data row3 col2" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col3" class="data row3 col3" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col4" class="data row3 col4" >-1</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col5" class="data row3 col5" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col6" class="data row3 col6" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col7" class="data row3 col7" >-1</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col8" class="data row3 col8" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col9" class="data row3 col9" >-1</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row3_col10" class="data row3 col10" >0</td>
#     </tr>    <tr>
#         <th id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col0" class="data row4 col0" >2</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col1" class="data row4 col1" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col2" class="data row4 col2" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col3" class="data row4 col3" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col4" class="data row4 col4" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col5" class="data row4 col5" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col6" class="data row4 col6" >0</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col7" class="data row4 col7" >-1</td>
#         <td id="T_1edb01b6_3742_11e8_8b4b_aaa795456fa7row4_col8" class="data row4 col8" >0</td>
#         <td id="T_1ed

# %% [markdown]
# #### 将缺失值用NaN 替换

# %%
# 给特定值上色
def showHight(col):
    c = col =='NaN'
    #c = col ==col.max()
    return ['background-color:red' if v else ' ' for v in c]


def aggr(data):
    df = data.isnull().replace({True:'NaN',False:' '})
    df['.Row_Nums'] = 1

    df1 = df.groupby(by=list(data.columns)).agg(sum).sort_values('.Row_Nums',ascending =False).reset_index()
    df2 = data.isnull().sum().to_frame().T.rename(index = {0:' '})
    tem = pd.concat([df1,df2]).fillna('Missing_Nums')
    return tem.style.apply(showHight)

# %%
aggr(sleep)
# Out:
# <style  type="text/css" >
#     #T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col4 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col7 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col6 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col10 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col7 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col9 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row5_col4 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row5_col7 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row5_col9 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row6_col6 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row6_col10 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row7_col4 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row7_col7 {
#             background-color: red;
#         }    #T_2795960c_3742_11e8_89bd_aaa795456fa7row7_col10 {
#             background-color: red;
#         }</style>
# <table id="T_2795960c_3742_11e8_89bd_aaa795456fa7" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >.Row_Nums</th>
#         <th class="col_heading level0 col1" >BodyWgt</th>
#         <th class="col_heading level0 col2" >BrainWgt</th>
#         <th class="col_heading level0 col3" >Danger</th>
#         <th class="col_heading level0 col4" >Dream</th>
#         <th class="col_heading level0 col5" >Exp</th>
#         <th class="col_heading level0 col6" >Gest</th>
#         <th class="col_heading level0 col7" >NonD</th>
#         <th class="col_heading level0 col8" >Pred</th>
#         <th class="col_heading level0 col9" >Sleep</th>
#         <th class="col_heading level0 col10" >Span</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2795960c_3742_11e8_89bd_aaa795456fa7level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col0" class="data row0 col0" >42</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col1" class="data row0 col1" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col2" class="data row0 col2" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col3" class="data row0 col3" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col4" class="data row0 col4" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col5" class="data row0 col5" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col6" class="data row0 col6" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col7" class="data row0 col7" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col8" class="data row0 col8" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col9" class="data row0 col9" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row0_col10" class="data row0 col10" > </td>
#     </tr>    <tr>
#         <th id="T_2795960c_3742_11e8_89bd_aaa795456fa7level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col0" class="data row1 col0" >9</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col1" class="data row1 col1" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col2" class="data row1 col2" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col3" class="data row1 col3" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col4" class="data row1 col4" >NaN</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col5" class="data row1 col5" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col6" class="data row1 col6" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col7" class="data row1 col7" >NaN</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col8" class="data row1 col8" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col9" class="data row1 col9" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row1_col10" class="data row1 col10" > </td>
#     </tr>    <tr>
#         <th id="T_2795960c_3742_11e8_89bd_aaa795456fa7level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col0" class="data row2 col0" >3</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col1" class="data row2 col1" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col2" class="data row2 col2" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col3" class="data row2 col3" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col4" class="data row2 col4" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col5" class="data row2 col5" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col6" class="data row2 col6" >NaN</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col7" class="data row2 col7" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col8" class="data row2 col8" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col9" class="data row2 col9" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row2_col10" class="data row2 col10" > </td>
#     </tr>    <tr>
#         <th id="T_2795960c_3742_11e8_89bd_aaa795456fa7level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col0" class="data row3 col0" >2</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col1" class="data row3 col1" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col2" class="data row3 col2" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col3" class="data row3 col3" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col4" class="data row3 col4" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col5" class="data row3 col5" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col6" class="data row3 col6" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col7" class="data row3 col7" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col8" class="data row3 col8" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col9" class="data row3 col9" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row3_col10" class="data row3 col10" >NaN</td>
#     </tr>    <tr>
#         <th id="T_2795960c_3742_11e8_89bd_aaa795456fa7level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col0" class="data row4 col0" >2</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col1" class="data row4 col1" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col2" class="data row4 col2" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col3" class="data row4 col3" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col4" class="data row4 col4" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col5" class="data row4 col5" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col6" class="data row4 col6" > </td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col7" class="data row4 col7" >NaN</td>
#         <td id="T_2795960c_3742_11e8_89bd_aaa795456fa7row4_col8" class="data row4 col8" > </td>
#         <td id="T_

# %%
import pandas as pd #数据分析
import numpy as np #科学计算
from pandas import Series,DataFrame

import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns

matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
# %load_ext watermark

# %%
# %watermark -d -v -m -p twitter,pyprind,wordcloud,pandas,scipy,matplotlib
# Out:
# 2018-03-13
#
# CPython 3.6.2
# IPython 6.1.0
#
# twitter n
# pyprind 2.11.1
# wordcloud 1.3.3
# pandas 0.20.3
# scipy 1.0.0
# matplotlib 2.0.2
#
# compiler   : MSC v.1900 64 bit (AMD64)
# system     : Windows
# release    : 10
# machine    : AMD64
# processor  : Intel64 Family 6 Model 78 Stepping 3, GenuineIntel
# CPU cores  : 4
# interpreter: 64bit

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
from  wordcloud import WordCloud

# %%
# data =pd.read_pickle('d:/Python/Kaggle_data/Titanic/title_counts.pkl')
# data.set_index(data['index'],inplace=True)
# data.drop('index',axis =1,inplace =True)
# data1 = str(data)  # 关键一步
# data
data = pd.read_csv('d:\\Python\\temp1.csv',header =None,encoding ='utf-8')
data1 = str(data)

# %%
data2 =dict(data)  #待证明

# %%
mask_pic = np.array(Image.open('D:\\Python\\timg12.jpg'))
stopwords = set(STOPWORDS)

# %%
wc = WordCloud(#font_path = 'C:\\Users\\Administrator.DESKTOP-8UOSO1O\\Downloads\\cabin-sketch.bold.ttf',
               font_path = 'C:\\Windows\\Fonts\\msyhbd.ttc', #SIMYOU.ttf   msyhbd.ttc
               background_color ="white", 
               max_words=2000, 
               mask=mask_pic, #罩面图
               stopwords=stopwords, 
               max_font_size=75, 
               random_state=42)

# %%
wc.generate(data1)
# 从图片上取色
image_colors = ImageColorGenerator(mask_pic)
plt.imshow(wc.recolor(color_func = image_colors),interpolation = "bilinear")
plt.axis('off')
#wc.to_file('Pika_cloud10.png')  # wordcloud 自带方法
plt.savefig('Pika_cloud14.png', dpi=300)  # 在show（） 之前
plt.show()

# %%
wc.generate(data1)
# 从图片上取色
image_colors = ImageColorGenerator(mask_pic)

plt.imshow(wc)
plt.axis('off')
plt.savefig('Pika_cloud.png', dpi=300)  # 在show（） 之前
plt.show()

# %% [markdown]
# ### 云图保存
# - wc.to_file()
# - plt.savefig()
